# %%
from pvComm import pvComm
from scanBNP import getCoordinate_ptycho, get_ptycho_data_positions

scandict = {}
scandict['n_clusters'] = 5
scandict['sel_cluster'] = 4
coarse_sc = 'bnp_fly0009.mda'
p = pvComm()
d = getCoordinate_ptycho(p, coarse_sc, scandict)

# %%
coarse_sc = 'bnp_fly0009.mda'
# p = pvComm()
userdir = '/mnt/micdata1/bnp/2025-3/Rodriguez'
d = get_ptycho_data_positions(coarse_sc, userdir)
# Out:
# /mnt/micdata1/bnp/2025-3/Rodriguez/mda/bnp_fly0009.mda
# /mnt/micdata1/bnp/2025-3/Rodriguez/ptychi_recons/S0009/Ndp64_LSQML_s800_gaussian_p10_cp_mm_opr3_ic_pc0_f_ul2/object_ph/object_ph_Niter200.tiff

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(4, 4), dpi=100)
a = np.zeros((100, 100))
im = ax.imshow(a, cmap='viridis', origin='lower')
ax.set_title('Zero array test')
fig.colorbar(im, ax=ax, shrink=0.8)
plt.show()
